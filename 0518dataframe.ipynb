# %%
import pandas as pd

# %%
customerData = pd.read_csv("E:/kopocloud/dataset/customerdata.csv")

# %%
sortKey = ["AVGPRICE"]

# %%
customerData
# Out:
#      CUSTID     AVGPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE
# 0    A13566  4273.900000    3            6    1.679181  Big-Screen-lover
# 1    A14219  3642.441950    2            4    2.682023      Sleeping-dog
# 2    A15312  3653.884565    2            5    3.208202      Sleeping-dog
# 3    A16605  3713.211107    2            6    0.900000        Early-bird
# 4    B10634  3391.074215    2            4    2.453656      Sleeping-dog
# 5    B16849  3755.263391    2            4    2.786665      Sleeping-dog
# 6    B18816  3213.911446    2            6    0.900000        Early-bird
# 7    C10639  3516.500000    2            5    2.564830  Big-Screen-lover
# 8    C12717  3732.900000    2            5    2.069995  Big-Screen-lover
# 9    C15050  4020.173425    2            4    3.013440      Sleeping-dog
# 10   C18306  4005.005142    2            4    3.113618      Sleeping-dog
# 11   C18622  3246.000000    1            5    1.891624  Big-Screen-lover
# ...

# %%
customerData.sort_values(by=sortKey) ##이경우에는 저장안됨
# Out:
#      CUSTID     AVGPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE
# 68   N14862  2390.083736    1            6    1.000000        Early-bird
# 131  W13995  2411.008838    2            6    1.000000        Early-bird
# 125  V16704  2605.631083    2            6    0.900000        Early-bird
# 58   K16632  2650.900000    2            4    2.233033  Big-Screen-lover
# 30   G11453  2744.815881    2            6    0.900000        Early-bird
# 105  S15966  2797.678314    2            6    0.900000        Early-bird
# 48   I17780  2804.267157    2            6    0.900000        Early-bird
# 52   J15083  2811.265932    3            6    0.900000        Early-bird
# 108  S17893  2857.684730    2            3    2.679795      Sleeping-dog
# 94   R15454  2868.195533    2            6    1.000000        Early-bird
# 37   G19717  2873.102202    2            6    0.800000        Early-bird
# 112  T11116  2890.703076    2            3    2.303318      Sleeping-dog
# ...

# %%
sortedData = customerData.sort_values(by=sortKey)
print(sortedData)
# Out:
#      CUSTID     AVGPRICE  EMI  DEVICECOUNT  PRODUCTAGE          CUSTTYPE
# 68   N14862  2390.083736    1            6    1.000000        Early-bird
# 131  W13995  2411.008838    2            6    1.000000        Early-bird
# 125  V16704  2605.631083    2            6    0.900000        Early-bird
# 58   K16632  2650.900000    2            4    2.233033  Big-Screen-lover
# 30   G11453  2744.815881    2            6    0.900000        Early-bird
# 105  S15966  2797.678314    2            6    0.900000        Early-bird
# 48   I17780  2804.267157    2            6    0.900000        Early-bird
# 52   J15083  2811.265932    3            6    0.900000        Early-bird
# 108  S17893  2857.684730    2            3    2.679795      Sleeping-dog
# 94   R15454  2868.195533    2            6    1.000000        Early-bird
# 37   G19717  2873.102202    2            6    0.800000        Early-bird
# 112  T11116  2890.703076    2            3    2.303318      Sleeping-dog
# ...

# %%
customerData.sort_values(by=sortKey, 
                         inplace = True,
                        ignore_index = True)
#ignore_index의 경우 기존 인덱스를 무시하고 출력한다는 옵션, 최신 판다스의 경우 가능
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-2fab8bb42a54> in <module>
#       1 customerData.sort_values(by=sortKey,
#       2                          inplace = True,
# ----> 3                         ignore_index = True)
#       4 #ignore_index의 경우 기존 인덱스를 무시하고 출력한다는 옵션
#
# TypeError: sort_values() got an unexpected keyword argument 'ignore_index'

# %%
sortKey = ["AVGPRICE", "PRODUCTAGE"]

# %%
customerData.sort_values(by = [sortKey],
                        ascending = [True, False])

#다시 학습필요

print(customerData)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-57653be575aa> in <module>
#       1 customerData.sort_values(by = [sortKey],
# ----> 2                         ascending = [True, False])
#       3
#       4 print(customerData)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    4704         if is_sequence(ascending) and len(by) != len(ascending):
#    4705             raise ValueError('Length of ascending (%d) != length of by (%d)' %
# -> 4706                              (len(ascending), len(by)))
#    4707         if len(by) > 1:
#    4708             from pandas.core.sorting import lexsort_indexer
#
# ValueError: Length of ascending (2) != length of by (1)

# %%
groupKey = ["EMI"]

groupData = customerData.groupby(by=groupKey)["AVGPRICE"].agg(["mean"])

groupDataResult = groupData.reset_index()

# %%
groupDataResult.rename(columns={'mean':'AVG_MEAN'},
                      inplace = True)
